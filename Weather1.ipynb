# %% [markdown]
# ### Question: Predicting # of Flight delays given certain weather and past flight data

# %%
import pandas as pd
import numpy as np

# %%
# Read in csv files from Kaggle
pressure_df = pd.read_csv('weather_data/pressure.csv')
humidity_df = pd.read_csv('weather_data/humidity.csv')
temperature_df = pd.read_csv('weather_data/temperature.csv')
wind_direction_df = pd.read_csv('weather_data/wind_direction.csv')
wind_speed_df = pd.read_csv('weather_data/wind_speed.csv')
weather_description_df = pd.read_csv("weather_data/weather_description.csv")

# %%
# Top 5 cities with most values in flight delay dataset
cities = ["Atlanta",'Chicago','Dallas','Charlotte','Denver']

# %%
def clean_df(dataframe,name):
    dataframe = dataframe[["datetime"] + cities] # call subset of df
    dataframe_2015_index = list(dataframe.index[dataframe['datetime'] == "2015-01-01 00:00:00"])
    # going from 2015 - 2017
    dataframe = dataframe.iloc[dataframe_2015_index[0]:,:]
    # add name to columns specifying originating df. Need this specified when joining table
    new_names = dict(zip(list(cities),list(np.core.defchararray.add(cities,name))))
    new_names['datetime'] = 'datetime'
    dataframe = dataframe.rename(columns = new_names)
    return dataframe

# %%
# New cleaned and correctly labeled df
pressure_df = clean_df(pressure_df, '_pressure')
humidity_df = clean_df(humidity_df, '_humidity')
temperature_df = clean_df(temperature_df, '_temperature')
wind_direction_df = clean_df(wind_direction_df, '_wind_direction')
wind_speed_df = clean_df(wind_speed_df, '_wind_speed')
weather_description_df = clean_df(weather_description_df, '_description')

# %%
# Merge the individual datasets on datetime
A = pd.merge(pressure_df.merge(humidity_df, how = 'outer'),temperature_df, how = 'outer')
B = pd.merge(wind_direction_df.merge(wind_speed_df, how = 'outer'), weather_description_df, how = 'outer')
weather_df = A.merge(B, how = 'outer')

# %%
weather_df.head()
# weather.columns
# Out:
#               datetime  Atlanta_pressure  Chicago_pressure  Dallas_pressure  \
# 0  2015-01-01 00:00:00            1042.0            1039.0           1047.0
# 1  2015-01-01 01:00:00            1043.0            1037.0           1047.0
# 2  2015-01-01 02:00:00            1043.0            1037.0           1046.0
# 3  2015-01-01 03:00:00            1043.0            1037.0           1046.0
# 4  2015-01-01 04:00:00            1043.0            1037.0           1046.0
#
#    Charlotte_pressure  Denver_pressure  Atlanta_humidity  Chicago_humidity  \
# 0              1042.0           1046.0              79.0             100.0
# 1              1042.0           1046.0              78.0             100.0
# 2              1042.0           1047.0              80.0             100.0
# 3              1042.0           1046.0              78.0             100.0
# 4              1042.0           1047.0              81.0             100.0
#
#    Dallas_humidity  Charlotte_humidity         ...          \
# 0             76.0                81.0         ...
# 1             74.0                92.0         ...
# 2             76.0                89.0         ...
# 3             75.0                91.0         ...
# 4             78.0                86.0         ...
#
#    Atlanta_wind_speed  Chicago_wind_speed  Dallas_wind_speed  \
# 0                 1.0                 9.0                4.0
# 1                 2.0                10.0                4.0
# 2                 1.0                10.0                3.0
# 3                 1.0                10.0                3.0
# 4                 1.0                10.0                3.0
#
#    Charlotte_wind_speed  Denver_wind_speed  Atlanta_description  \
# 0                   1.0                1.0         sky is clear
# 1                   1.0                1.0         sky is clear
# 2                   1.0                1.0         sky is clear
# 3                   1.0                1.0         sky is clear
# 4                   1.0                1.0         sky is clear
#
#    Chicago_description  Dallas_description  Charlotte_description  \
# 0         sky is clear     overcast clouds           sky is clear
# 1         sky is clear       broken clouds           sky is clear
# 2         sky is clear     overcast clouds           sky is clear
# 3         sky is clear       broken clouds           sky is clear
# 4         sky is clear     overcast clouds           sky is clear
#
#    Denver_description
# 0        sky is clear
# 1        sky is clear
# 2        sky is clear
# 3        sky is clear
# 4        sky is clear
#
# [5 rows x 31 columns]

# %%
# Check for column names that have null values
null_list = list(weather_df.columns[weather_df.isna().any()])
for column in null_list:
    # check missing values ratio to dataset size
    print(column, (weather_df[column].isna().sum()/weather_df.shape[0])*100)
    
# Output:
# Chicago_pressure 0.003915886752555116
# Atlanta_humidity 0.07440184829854721
# Chicago_humidity 0.003915886752555116
# Dallas_humidity 0.12922426283431884
# Charlotte_humidity 0.775345577005913
# Denver_humidity 0.01174766025766535
# Dallas_wind_speed 0.003915886752555116
# Charlotte_wind_speed 0.003915886752555116

# Since they're so minute, will just drop rows that have null values
# Out:
# Chicago_pressure 0.003915886752555116
# Atlanta_humidity 0.07440184829854721
# Chicago_humidity 0.003915886752555116
# Dallas_humidity 0.12922426283431884
# Charlotte_humidity 0.775345577005913
# Denver_humidity 0.01174766025766535
# Dallas_wind_speed 0.003915886752555116
# Charlotte_wind_speed 0.003915886752555116

# %%
weather_df.shape # 25537 rows
weather_df = weather_df.dropna()
weather_df.shape # 240 rows dropped
# Out:
# (25297, 31)

# %%
weather_df.head()
# Out:
#               datetime  Atlanta_pressure  Chicago_pressure  Dallas_pressure  \
# 0  2015-01-01 00:00:00            1042.0            1039.0           1047.0
# 1  2015-01-01 01:00:00            1043.0            1037.0           1047.0
# 2  2015-01-01 02:00:00            1043.0            1037.0           1046.0
# 3  2015-01-01 03:00:00            1043.0            1037.0           1046.0
# 4  2015-01-01 04:00:00            1043.0            1037.0           1046.0
#
#    Charlotte_pressure  Denver_pressure  Atlanta_humidity  Chicago_humidity  \
# 0              1042.0           1046.0              79.0             100.0
# 1              1042.0           1046.0              78.0             100.0
# 2              1042.0           1047.0              80.0             100.0
# 3              1042.0           1046.0              78.0             100.0
# 4              1042.0           1047.0              81.0             100.0
#
#    Dallas_humidity  Charlotte_humidity         ...          \
# 0             76.0                81.0         ...
# 1             74.0                92.0         ...
# 2             76.0                89.0         ...
# 3             75.0                91.0         ...
# 4             78.0                86.0         ...
#
#    Atlanta_wind_speed  Chicago_wind_speed  Dallas_wind_speed  \
# 0                 1.0                 9.0                4.0
# 1                 2.0                10.0                4.0
# 2                 1.0                10.0                3.0
# 3                 1.0                10.0                3.0
# 4                 1.0                10.0                3.0
#
#    Charlotte_wind_speed  Denver_wind_speed  Atlanta_description  \
# 0                   1.0                1.0         sky is clear
# 1                   1.0                1.0         sky is clear
# 2                   1.0                1.0         sky is clear
# 3                   1.0                1.0         sky is clear
# 4                   1.0                1.0         sky is clear
#
#    Chicago_description  Dallas_description  Charlotte_description  \
# 0         sky is clear     overcast clouds           sky is clear
# 1         sky is clear       broken clouds           sky is clear
# 2         sky is clear     overcast clouds           sky is clear
# 3         sky is clear       broken clouds           sky is clear
# 4         sky is clear     overcast clouds           sky is clear
#
#    Denver_description
# 0        sky is clear
# 1        sky is clear
# 2        sky is clear
# 3        sky is clear
# 4        sky is clear
#
# [5 rows x 31 columns]

# %%
# Split datetime column into Years, Months, Days and time column
Year = []
Month = []
Day = []
Time = []
for datetime in weather_df['datetime']:
    date, time = datetime.split(' ')
    year, month, day = date.split('-')
    Year.append(year)
    Month.append(month)
    Day.append(day)
    Time.append(time)

# Convert arrays to pandas Series and make it int type, so when merging, the object-type will be same
weather_df['Year'] = pd.Series(Year, dtype='int32')
weather_df["Month"] = pd.Series(Month, dtype='int32')
weather_df['Day'] = pd.Series(Day, dtype='int32')
weather_df['Time'] = Time

# %%
# Rearranging them so date/time is in beginning
weather_df = weather_df[['Year', 'Month', 'Day','Time','Atlanta_pressure', 'Chicago_pressure', 'Dallas_pressure',\
       'Charlotte_pressure', 'Denver_pressure', 'Atlanta_humidity',\
       'Chicago_humidity', 'Dallas_humidity', 'Charlotte_humidity',\
       'Denver_humidity', 'Atlanta_temperature', 'Chicago_temperature',\
       'Dallas_temperature', 'Charlotte_temperature', 'Denver_temperature',\
       'Atlanta_wind_direction', 'Chicago_wind_direction',\
       'Dallas_wind_direction', 'Charlotte_wind_direction',\
       'Denver_wind_direction', 'Atlanta_wind_speed', 'Chicago_wind_speed',\
       'Dallas_wind_speed', 'Charlotte_wind_speed', 'Denver_wind_speed',\
       'Atlanta_description', 'Chicago_description', 'Dallas_description',\
       'Charlotte_description', 'Denver_description']]
weather_df.head()
# Out:
#      Year  Month  Day      Time  Atlanta_pressure  Chicago_pressure  \
# 0  2015.0    1.0  1.0  00:00:00            1042.0            1039.0
# 1  2015.0    1.0  1.0  01:00:00            1043.0            1037.0
# 2  2015.0    1.0  1.0  02:00:00            1043.0            1037.0
# 3  2015.0    1.0  1.0  03:00:00            1043.0            1037.0
# 4  2015.0    1.0  1.0  04:00:00            1043.0            1037.0
#
#    Dallas_pressure  Charlotte_pressure  Denver_pressure  Atlanta_humidity  \
# 0           1047.0              1042.0           1046.0              79.0
# 1           1047.0              1042.0           1046.0              78.0
# 2           1046.0              1042.0           1047.0              80.0
# 3           1046.0              1042.0           1046.0              78.0
# 4           1046.0              1042.0           1047.0              81.0
#
#           ...          Atlanta_wind_speed  Chicago_wind_speed  \
# 0         ...                         1.0                 9.0
# 1         ...                         2.0                10.0
# 2         ...                         1.0                10.0
# 3         ...                         1.0                10.0
# 4         ...                         1.0                10.0
#
#    Dallas_wind_speed  Charlotte_wind_speed  Denver_wind_speed  \
# 0                4.0                   1.0                1.0
# 1                4.0                   1.0                1.0
# 2                3.0                   1.0                1.0
# 3                3.0                   1.0                1.0
# 4                3.0                   1.0                1.0
#
#    Atlanta_description  Chicago_description  Dallas_description  \
# 0         sky is clear         sky is clear     overcast clouds
# 1         sky is clear         sky is clear       broken clouds
# 2         sky is clear         sky is clear     overcast clouds
# 3         sky is clear         sky is clear       broken clouds
# 4         sky is clear         sky is clear     overcast clouds
#
#    Charlotte_description  Denver_description
# 0           sky is clear        sky is clear
# 1           sky is clear        sky is clear
# 2           sky is clear        sky is clear
# 3           sky is clear        sky is clear
# 4           sky is clear        sky is clear
#
# [5 rows x 34 columns]

# %%
weather_df['hour']= pd.to_datetime(weather_df['Time']).dt.hour
weather_df["DayofMonth"]=weather_df["Day"]
weather_df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Time', 'Atlanta_pressure', 'Chicago_pressure',
#        'Dallas_pressure', 'Charlotte_pressure', 'Denver_pressure',
#        'Atlanta_humidity', 'Chicago_humidity', 'Dallas_humidity',
#        'Charlotte_humidity', 'Denver_humidity', 'Atlanta_temperature',
#        'Chicago_temperature', 'Dallas_temperature', 'Charlotte_temperature',
#        'Denver_temperature', 'Atlanta_wind_direction',
#        'Chicago_wind_direction', 'Dallas_wind_direction',
#        'Charlotte_wind_direction', 'Denver_wind_direction',
#        'Atlanta_wind_speed', 'Chicago_wind_speed', 'Dallas_wind_speed',
#        'Charlotte_wind_speed', 'Denver_wind_speed', 'Atlanta_description',
#        'Chicago_description', 'Dallas_description', 'Charlotte_description',
#        'Denver_description', 'hour', 'DayofMonth'],
#       dtype='object')

# %%
#break up to have columsn year mondy time and pressure, humidyt, wind speed and Charlotte_description for EACH CITY TO concate to datalist 
#Add origin as the symbol of the airport 
#combine 
Atlanta1= weather_df[['Year', 'Month', 'DayofMonth', 'Time',"hour","Atlanta_pressure","Atlanta_humidity","Atlanta_wind_direction","Atlanta_description"]]
Chicago1=weather_df[['Year', 'Month', 'DayofMonth', 'Time',"hour","Chicago_pressure","Chicago_humidity","Chicago_wind_direction","Chicago_description"]]
Denver1=weather_df[['Year', 'Month', 'DayofMonth', 'Time',"hour","Denver_pressure","Denver_humidity","Denver_wind_direction","Denver_description"]]
Dallas1=weather_df[['Year', 'Month', 'DayofMonth', 'Time',"hour","Dallas_pressure","Dallas_humidity","Dallas_wind_direction","Dallas_description"]]
Charlotte1=weather_df[['Year', 'Month', 'DayofMonth', 'Time',"hour","Charlotte_pressure","Charlotte_humidity","Charlotte_wind_direction","Charlotte_description"]]

# %%
# Atlanta1["Origin"]=("ATL")
Atlanta1 = Atlanta1.assign(Origin="ATL")
Chicago1= Chicago1.assign(Origin="ORD")
Denver1= Denver1.assign(Origin="DEN")
Dallas1= Dallas1.assign(Origin="DFW")
Charlotte1= Charlotte1.assign(Origin="CTL")

# %%
Atlanta1
Chicago1
# (Denver1[Denver1["Year"]].isna())
print(len(Denver1["Year"])) #25297
Denver1["Year"].isnull().sum() #2240 
# Dallas1.tail()
# Charlotte1
# Out:
# 25297
# 240

# %%
Atlanta1
# Out:
#          Year  Month  DayofMonth      Time  hour  Atlanta_pressure  \
# 0      2015.0    1.0         1.0  00:00:00     0            1042.0
# 1      2015.0    1.0         1.0  01:00:00     1            1043.0
# 2      2015.0    1.0         1.0  02:00:00     2            1043.0
# 3      2015.0    1.0         1.0  03:00:00     3            1043.0
# 4      2015.0    1.0         1.0  04:00:00     4            1043.0
# 5      2015.0    1.0         1.0  05:00:00     5            1043.0
# 6      2015.0    1.0         1.0  06:00:00     6            1043.0
# 7      2015.0    1.0         1.0  07:00:00     7            1042.0
# 8      2015.0    1.0         1.0  08:00:00     8            1042.0
# 9      2015.0    1.0         1.0  09:00:00     9            1042.0
# 10     2015.0    1.0         1.0  10:00:00    10            1042.0
# 11     2015.0    1.0         1.0  11:00:00    11            1042.0
# 12     2015.0    1.0         1.0  12:00:00    12            1042.0
# 13     2015.0    1.0         1.0  13:00:00    13            1042.0
# 14     2015.0    1.0         1.0  14:00:00    14            1042.0
# 15     2015.0    1.0         1.0  15:00:00    15            1041.0
# 16     2015.0    1.0         1.0  16:00:00    16            1041.0
# 17     2015.0    1.0         1.0  17:00:00    17            1040.0
# 18     2015.0    1.0         1.0  18:00:00    18            1040.0
# 19     2015.0    1.0         1.0  19:00:00    19            1039.0
# 20     2015.0    1.0         1.0  20:00:00    20            1039.0
# 21     2015.0    1.0         1.0  21:00:00    21            1040.0
# 22     2015.0    1.0         1.0  22:00:00    22            1039.0
# 23     2015.0    1.0         1.0  23:00:00    23            1039.0
# 24     2015.0    1.0         2.0  00:00:00     0            1039.0
# 25     2015.0    1.0         2.0  01:00:00     1            1040.0
# 26     2015.0    1.0         2.0  02:00:00     2            1040.0
# 27     2015.0    1.0         2.0  03:00:00     3            1039.0
# 28     2015.0    1.0         2.0  04:00:00     4            1040.0
# 29     2015.0    1.0         2.0  05:00:00     5            1040.0
# ...       ...    ...         ...       ...   ...               ...
# 25507     NaN    NaN         NaN  19:00:00    19            1025.0
# 25508     NaN    NaN         NaN  20:00:00    20            1024.0
# 25509     NaN    NaN         NaN  21:00:00    21            1024.0
# 25510     NaN    NaN         NaN  22:00:00    22            1025.0
# 25511     NaN    NaN         NaN  23:00:00    23            1025.0
# 25512     NaN    NaN         NaN  00:00:00     0            1025.0
# 25513     NaN    NaN         NaN  01:00:00     1            1025.0
# 25514     NaN    NaN         NaN  02:00:00     2            1026.0
# 25515     NaN    NaN         NaN  03:00:00     3            1026.0
# 25516     NaN    NaN         NaN  04:00:00     4            1026.0
# 25517     NaN    NaN         NaN  05:00:00     5            1026.0
# 25518     NaN    NaN         NaN  06:00:00     6            1026.0
# 25519     NaN    NaN         NaN  07:00:00     7            1026.0
# 25520     NaN    NaN         NaN  08:00:00     8            1026.0
# 25521     NaN    NaN         NaN  09:00:00     9            1026.0
# 25522     NaN    NaN         NaN  10:00:00    10            1026.0
# 25523     NaN    NaN         NaN  11:00:00    11            1026.0
# 25524     NaN    NaN         NaN  12:00:00    12            1027.0
# 25525     NaN    NaN         NaN  13:00:00    13            1026.0
# 25526     NaN    NaN         NaN  14:00:00    14            1026.0
# 25527     NaN    NaN         NaN  15:00:00    15            1027.0
# 25528     NaN    NaN         NaN  16:00:00    16            1026.0
# 25529     NaN    NaN         NaN  17:00:00    17            1026.0
# 25530     NaN    NaN         NaN  18:00:00    18            1026.0
# 25531     NaN    NaN         NaN  19:00:00    19            1025.0
# 25532     NaN    NaN         NaN  20:00:00    20            1024.0
# 25533     NaN    NaN         NaN  21:00:00    21            1023.0
# 25534     NaN    NaN         NaN  22:00:00    22            1023.0
# 25535     NaN    NaN         NaN  23:00:00    23            1023.0
# 25536     NaN    NaN         NaN  00:00:00     0            1024.0
#
#        Atlanta_humidity  Atlanta_wind_direction Atlanta_description Origin
# 0                  79.0                   344.0        sky is clear    ATL
# 1                  78.0                   342.0        sky is clear    ATL
# 2                  80.0                   342.0        sky is clear    ATL
# 3                  78.0                   324.0        sky is clear    ATL
# 4                  81.0                   330.0        sky is clear    ATL
# 5                  80.0                   317.0          few clouds    ATL
# 6                  80.0                   329.0        sky is clear    ATL
# 7                  79.0                   308.0          few clouds    ATL
# 8                  79.0                   312.0        sky is clear    ATL
# 9                  78.0                   311.0        sky is clear    ATL
# 10                 79.0                   316.0        sky is clear    ATL
# 11                 78.0                   316.0        sky is clear    ATL
# 12                 73.0                   323.0        sky is clear    ATL
# 13                 74.0                   321.0        sky is clear    ATL
# 14                 70.0                   325.0        sky is clear    ATL
# 15                 74.0                   266.0        sky is clear    ATL
# 16                 67.0                   291.0        sky is clear    ATL
# 17                 69.0                   254.0        sky is clear    ATL
# 18                 66.0                   306.0        sky is clear    ATL
# 19                 69.0                   239.0        sky is clear    ATL
# 20                 67.0                   261.0        sky is clear    ATL
# 21                 72.0                   283.0    scattered clouds    ATL
# 22                 69.0                   306.0          few clouds    ATL
# 23                 72.0                   328.0    scattered clouds    ATL
# 24                 65.0                   317.0    scattered clouds    ATL
# 25                 71.0                   350.0       broken clouds    ATL
# 26                 67.0                   350.0       broken clouds    ATL
# 27                 73.0                   186.0       broken clouds    ATL
# 28                 66.0                   240.0       broken clouds    ATL
# 29                 69.0                   131.0       broken clouds    ATL
# ...                 ...                     ...                 ...    ...
# 25507              37.0                   160.0        sky is clear    ATL
# 25508              34.0                   153.0        sky is clear    ATL
# 25509              37.0                   130.0        sky is clear    ATL
# 25510              40.0                   140.0        sky is clear    ATL
# 25511              40.0                   140.0        sky is clear    ATL
# 25512              51.0                   120.0        sky is clear    ATL
# 25513              58.0                   140.0        sky is clear    ATL
# 25514              62.0                   140.0        sky is clear    ATL
# 25515              66.0                   106.0        sky is clear    ATL
# 25516              66.0                   140.0        sky is clear    ATL
# 25517              71.0                    89.0        sky is clear    ATL
# 25518              61.0                    70.0    scattered clouds    ATL
# 25519              81.0                    89.0          few clouds    ATL
# 25520              93.0                    35.0                mist    ATL
# 25521              87.0                    66.0                mist    ATL
# 25522             100.0                    20.0                mist    ATL
# 25523              93.0                    56.0                 fog    ATL
# 25524             100.0                    56.0                 fog    ATL
# 25525             100.0                    80.0                mist    ATL
# 25526             100.0                    60.0                mist    ATL
# 25527             100.0                    88.0                mist    ATL
# 25528             100.0                    88.0                 fog    ATL
# 25529              93.0                   290.0                 fog    ATL
# 25530              93.0                   270.0                 fog    ATL
# 25531              93.0                   210.0                mist    ATL
# 25532              82.0                   146.0                mist    ATL
# 25533              73.0                   100.0                mist    ATL
# 25534              77.0                   146.0                haze    ATL
# 25535              82.0                   126.0       broken clouds    ATL
# 25536             100.0                   126.0                 fog    ATL
#
# [25297 rows x 10 columns]
